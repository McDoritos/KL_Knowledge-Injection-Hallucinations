# %% [markdown]
# ### Qwen3
# We will be using models from the Qwen3 family:
# - Qwen3-8B
# - Qwen3-4B
# - Qwen3-1.7B
#
# The models were downlaoded from Ollama: [https://ollama.com/library/qwen3]

# %%
from ollama import chat
from ollama import ChatResponse

# %%
response: ChatResponse = chat(model='qwen3:1.7b', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# The sky appears blue due to a phenomenon called **Rayleigh scattering**, which occurs when sunlight interacts with the molecules and small particles in the Earth's atmosphere. Here's why:
#
# 1. **Light Scattering**: Sunlight consists of different wavelengths, with violet and blue light having shorter wavelengths. When sunlight enters the atmosphere, it collides with molecules like nitrogen and oxygen. These collisions scatter the light in all directions.
#
# 2. **Wavelength Preference**: Shorter wavelengths (like blue and violet) are scattered more efficiently than longer wavelengths (like red and yellow). This means blue light is spread out more uniformly across the sky, while violet light is scattered but less prominently.
#
# 3. **Human Vision**: Our eyes are more sensitive to blue light than violet. Even though both wavelengths are scattered, the human eye's sensitivity to blue contributes to the perception of the sky as blue.
#
# ...

# %%
response: ChatResponse = chat(model='qwen3:4b', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# The sky appears blue primarily due to **Rayleigh scattering**—a physical process where sunlight interacts with the gases and particles in Earth's atmosphere. Here's a clear, step-by-step explanation:
#
# ---
#
# ### 1. **Sunlight is white light, but it contains all colors**
#    - Sunlight (visible light) is a mix of colors (wavelengths) ranging from red (longest wavelength, ~700 nm) to violet (shortest, ~400 nm).
#    - When sunlight enters Earth's atmosphere, it collides with nitrogen, oxygen, and tiny dust particles.
#
# ---
#
# ### 2. **Rayleigh scattering: Why blue scatters more**
#    - **How it works**: Light scatters more when the particles it hits are **much smaller than its wavelength** (like air molecules). This is called **Rayleigh scattering** (named after Lord Rayleigh).
#    - **Why blue?**: Shorter wavelengths (blue/violet light) scatter **much more strongly** than longer wavelengths (red/orange). Specifically:
#      - Scattering intensity ∝ **1 / (wavelength)⁴**
# ...

# %%
response: ChatResponse = chat(model='qwen3:8b', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# The sky appears blue due to a phenomenon called **Rayleigh scattering**, which involves how sunlight interacts with Earth's atmosphere. Here's a step-by-step explanation:
#
# 1. **Sunlight Composition**:
#    Sunlight is white, but it consists of a spectrum of colors (from violet to red). Each color has a different wavelength, with **blue/violet** having the shortest wavelengths and **red/orange** the longest.
#
# 2. **Atmospheric Interaction**:
#    When sunlight enters Earth's atmosphere, it collides with molecules (like nitrogen and oxygen) and small particles. These collisions **scatter light** in all directions. However, **shorter wavelengths** (blue and violet) are scattered more intensely than longer wavelengths (red, orange, etc.). This is because the scattering intensity is inversely proportional to the **fourth power of the wavelength** (Rayleigh scattering).
#
# 3. **Why Blue, Not Violet?**
#    - The sun emits more **blue light** than violet.
# ...
